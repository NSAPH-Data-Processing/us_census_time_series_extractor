# %%
import pandas as pd

# %%
#df = pd.read_parquet("data/intermediate/zcta__acs5__pct_foreign_born.parquet")
#df = pd.read_parquet("data/intermediate/zcta__acs5__pct_speak_english_less_than_very_well.parquet")
#df = pd.read_parquet("data/intermediate/zcta__acs5__pct_speak_spanish_at_home.parquet")
#df = pd.read_parquet("data/intermediate/zcta__acs5__pct_speak_spanish_at_home_english_less_than_very_well.parquet")
#df = pd.read_parquet("data/intermediate/zcta__acs5__pct_speak_asian_pacific_at_home.parquet")
#df = pd.read_parquet("data/intermediate/zcta__acs5__pct_speak_asian_pacific_at_home_english_less_than_very_well.parquet")
df = pd.read_parquet("data/intermediate/zcta__acs5__pct_hispanic.parquet")
#df = pd.read_parquet("data/intermediate/zcta__acs5__pct_asian_not_hispanic.parquet")

# %%
df.reset_index(inplace=True)
df
# Out:
#        survey  year   zcta  pct_hispanic
# 0        acs5  2009  00601     99.066530
# 1        acs5  2009  00602     93.501073
# 2        acs5  2009  00603     96.502983
# 3        acs5  2009  00606     99.718133
# 4        acs5  2009  00610     98.869843
# ...       ...   ...    ...           ...
# 398743   acs5  2020  99923      0.000000
# 398744   acs5  2020  99925      6.086957
# 398745   acs5  2020  99926      3.686007
# 398746   acs5  2020  99927      0.000000
# 398747   acs5  2020  99929      5.766526
#
# [398748 rows x 4 columns]

# %%
df[df.zcta == '90011']
# Out:
#        survey  year   zcta  pct_hispanic
# 30011    acs5  2009  90011     89.816101
# 63222    acs5  2010  90011     90.783840
# 93579    acs5  2011  90011     90.555302
# 129081   acs5  2012  90011     90.426131
# 153407   acs5  2013  90011     89.872955
# 187952   acs5  2014  90011     90.092782
# 201370   acs5  2015  90011     90.192594
# 261269   acs5  2016  90011     91.079752
# 277731   acs5  2017  90011     91.020555
# 311133   acs5  2018  90011     91.326411
# 361806   acs5  2019  90011     91.773429
# 395580   acs5  2020  90011     92.104072

# %%
df = pd.read_parquet("data/output/zcta__acs5_.parquet")
df[df.zcta == '90011']
# Out:
#        survey  year   zcta  pct_foreign_born  \
# 7126     acs5  2009  90011              50.6
# 58103    acs5  2010  90011              50.6
# 93579    acs5  2011  90011              49.2
# 126585   acs5  2012  90011              48.4
# 153407   acs5  2013  90011              47.6
# 187952   acs5  2014  90011              46.9
# 201370   acs5  2015  90011              45.7
# 256419   acs5  2016  90011              45.8
# 277731   acs5  2017  90011               0.7
# 311133   acs5  2018  90011               3.3
# 361806   acs5  2019  90011               3.0
# 395580   acs5  2020  90011               2.7
#
#         pct_speak_english_less_than_very_well  pct_speak_spanish_at_home  \
# 7126                                     48.9                       88.0
# 58103                                    49.0                       88.8
# 93579                                    48.1                       88.2
# 126585                                   46.8                       88.0
# ...

# %%
df = pd.read_parquet("data/output/zcta__acs5.parquet")
df[df.zcta == '90011']
# Out:
#        survey  year   zcta  pct_foreign_born  \
# 7126     acs5  2009  90011              50.6
# 58103    acs5  2010  90011              50.6
# 93579    acs5  2011  90011              49.2
# 126585   acs5  2012  90011              48.4
# 153407   acs5  2013  90011              47.6
# 187952   acs5  2014  90011              46.9
# 201370   acs5  2015  90011              45.7
# 256419   acs5  2016  90011              45.8
# 277731   acs5  2017  90011              45.5
# 311133   acs5  2018  90011              45.4
# 361806   acs5  2019  90011              45.5
# 395580   acs5  2020  90011              45.2
#
#         pct_speak_english_less_than_very_well  pct_speak_spanish_at_home  \
# 7126                                     48.9                       88.0
# 58103                                    49.0                       88.8
# 93579                                    48.1                       88.2
# 126585                                   46.8                       88.0
# ...
