# %%
import os
os.getcwd() # should be root of the project
# Out:
# '/net/rcstorenfs02/ifs/rc_labs/dominici_lab/lab/data_processing/michelle_us_census_time_series_extractor/michelle'

# %%
import censusdis.data as ced
import pandas as pd
import string

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # 65 plus explorer

# %%
def validate_xyear(var_variable, var_group, var_dataset, var_years):
    var_df = list() 
    for year in var_years:
        # identify whether group is a dictionary or string
        if isinstance(var_group, dict):
            group = var_group[year]
        elif isinstance(var_group, str):
            group = var_group
        # identify whether dataset is a dictionary or string
        if isinstance(var_dataset, dict):
            dataset = var_dataset[year]
        elif isinstance(var_dataset, str):
            dataset = var_dataset
        # identify whether variable is a dictionary or string
        if isinstance(var_variable, dict):
            variable = var_variable[year]
        elif isinstance(var_variable, str):
            variable = var_variable
        # make request
        var = ced.variables.all_variables(dataset, year, group)
        # make sure variable is in dataset
        if var.shape[0] == 0:
            print(f'{dataset} empty for {year}')
        elif var[var.VARIABLE == variable].shape[0] == 0:
            print(f'{variable} not found in {dataset} for {year}')
        else:
            var = var[["YEAR", "LABEL"]][var.VARIABLE == variable]
            var_df.append(var)
    var_df = pd.concat(var_df)
    return var_df

# %%
## acs5
acs_acs5_groups_2009 = ced.variables.all_groups('acs/acs5', year=2009)[['GROUP', 'DESCRIPTION']]
acs_acs5_groups_2009.to_csv('notes/acs_acs5_groups_2009.csv', index=False)
acs_acs5_groups_2009.head()
# Out:
#      GROUP                                   DESCRIPTION
# 0   B00001     UNWEIGHTED SAMPLE COUNT OF THE POPULATION
# 1   B00002               UNWEIGHTED SAMPLE HOUSING UNITS
# 2   B01001                                    SEX BY AGE
# 3  B01001A                      SEX BY AGE (WHITE ALONE)
# 4  B01001B  SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)

# %% [markdown]
# ## Poverty

# %% [markdown]
# ### B17001,POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE

# %%
print(acs_acs5_groups_2009[acs_acs5_groups_2009['GROUP'] == 'B17001'])
group = ced.variables.all_variables('acs/acs5', 2009, 'B17001')[['VARIABLE', 'LABEL']]
group.to_csv('notes/B17001_variables.csv', index=False)
group.head()
# Out:
#       GROUP                                         DESCRIPTION
# 186  B17001  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE
#       VARIABLE  \
# 0  B17001_001E
# 1  B17001_002E
# 2  B17001_003E
# 3  B17001_004E
# 4  B17001_005E
#
#                                                                                     LABEL
# 0                                                                         Estimate!!Total
# 1                       Estimate!!Total!!Income in the past 12 months below poverty level
# 2                 Estimate!!Total!!Income in the past 12 months below poverty level!!Male
# 3  Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!Under 5 years
# 4        Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!5 years

# %%
validate_xyear(f'B17001_015E', 'B17001', 'acs/acs5', range(2009, 2022+1))
# Out:
#     YEAR  \
# 14  2009
# 14  2010
# 14  2011
# 14  2012
# 14  2013
# 14  2014
# 14  2015
# 14  2016
# 14  2017
# 14  2018
# 14  2019
# 14  2020
# 14  2021
# 14  2022
#
#                                                                                          LABEL
# 14     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!65 to 74 years
# 14     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!65 to 74 years
# 14     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!65 to 74 years
# 14     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!65 to 74 years
# 14     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!65 to 74 years
# 14     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!65 to 74 years
# 14     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!65 to 74 years
# 14     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!65 to 74 years
# 14     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!65 to 74 years
# 14     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!65 to 74 years
# 14  Estimate!!Total:!!Income in the past 12 months below poverty level:!!Male:!!65 to 74 years
# 14  Estimate!!Total:!!Income in the past 12 months below poverty level:!!Male:!!65 to 74 years
# 14  Estimate!!Total:!!Income in the past 12 months below poverty level:!!Male:!!65 to 74 years
# 14  Estimate!!Total:!!Income in the past 12 months below poverty level:!!Male:!!65 to 74 years

# %%
validate_xyear(f'B17001_016E', 'B17001', 'acs/acs5', range(2009, 2022+1))
# Out:
#     YEAR  \
# 15  2009
# 15  2010
# 15  2011
# 15  2012
# 15  2013
# 15  2014
# 15  2015
# 15  2016
# 15  2017
# 15  2018
# 15  2019
# 15  2020
# 15  2021
# 15  2022
#
#                                                                                             LABEL
# 15     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!75 years and over
# 15     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!75 years and over
# 15     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!75 years and over
# 15     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!75 years and over
# 15     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!75 years and over
# 15     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!75 years and over
# 15     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!75 years and over
# 15     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!75 years and over
# 15     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!75 years and over
# 15     Estimate!!Total!!Income in the past 12 months below poverty level!!Male!!75 years and over
# 15  Estimate!!Total:!!Income in the past 12 months below poverty level:!!Male:!!75 years and over
# 15  Estimate!!Total:!!Income in the past 12 months below poverty level:!!Male:!!75 years and over
# 15  Estimate!!Total:!!Income in the past 12 months below poverty level:!!Male:!!75 years and over
# 15  Estimate!!Total:!!Income in the past 12 months below poverty level:!!Male:!!75 years and over

# %%
validate_xyear(f'B17001_029E', 'B17001', 'acs/acs5', range(2009, 2022+1))
# Out:
#     YEAR  \
# 28  2009
# 28  2010
# 28  2011
# 28  2012
# 28  2013
# 28  2014
# 28  2015
# 28  2016
# 28  2017
# 28  2018
# 28  2019
# 28  2020
# 28  2021
# 28  2022
#
#                                                                                            LABEL
# 28     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!65 to 74 years
# 28     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!65 to 74 years
# 28     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!65 to 74 years
# 28     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!65 to 74 years
# 28     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!65 to 74 years
# 28     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!65 to 74 years
# 28     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!65 to 74 years
# 28     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!65 to 74 years
# 28     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!65 to 74 years
# 28     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!65 to 74 years
# 28  Estimate!!Total:!!Income in the past 12 months below poverty level:!!Female:!!65 to 74 years
# 28  Estimate!!Total:!!Income in the past 12 months below poverty level:!!Female:!!65 to 74 years
# 28  Estimate!!Total:!!Income in the past 12 months below poverty level:!!Female:!!65 to 74 years
# 28  Estimate!!Total:!!Income in the past 12 months below poverty level:!!Female:!!65 to 74 years

# %%
validate_xyear(f'B17001_030E', 'B17001', 'acs/acs5', range(2009, 2022+1))
# Out:
#     YEAR  \
# 29  2009
# 29  2010
# 29  2011
# 29  2012
# 29  2013
# 29  2014
# 29  2015
# 29  2016
# 29  2017
# 29  2018
# 29  2019
# 29  2020
# 29  2021
# 29  2022
#
#                                                                                               LABEL
# 29     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!75 years and over
# 29     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!75 years and over
# 29     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!75 years and over
# 29     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!75 years and over
# 29     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!75 years and over
# 29     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!75 years and over
# 29     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!75 years and over
# 29     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!75 years and over
# 29     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!75 years and over
# 29     Estimate!!Total!!Income in the past 12 months below poverty level!!Female!!75 years and over
# 29  Estimate!!Total:!!Income in the past 12 months below poverty level:!!Female:!!75 years and over
# 29  Estimate!!Total:!!Income in the past 12 months below poverty level:!!Female:!!75 years and over
# 29  Estimate!!Total:!!Income in the past 12 months below poverty level:!!Female:!!75 years and over
# 29  Estimate!!Total:!!Income in the past 12 months below poverty level:!!Female:!!75 years and over

# %% [markdown]
# ### B17024,AGE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS

# %%
print(acs_acs5_groups_2009[acs_acs5_groups_2009['GROUP'] == 'B17024'])
group = ced.variables.all_variables('acs/acs5', 2009, 'B17024')[['VARIABLE', 'LABEL']]
group.to_csv('notes/B17024_variables.csv', index=False)
group.head()
# Out:
#       GROUP                                                    DESCRIPTION
# 224  B17024  AGE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS
#       VARIABLE                                       LABEL
# 0  B17024_001E                             Estimate!!Total
# 1  B17024_002E              Estimate!!Total!!Under 6 years
# 2  B17024_003E   Estimate!!Total!!Under 6 years!!Under .50
# 3  B17024_004E  Estimate!!Total!!Under 6 years!!.50 to .74
# 4  B17024_005E  Estimate!!Total!!Under 6 years!!.75 to .99
